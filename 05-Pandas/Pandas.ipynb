# %% [markdown]
# # Welcome to Pandas

# %%
import numpy as np
import pandas as pd

# %%
dict1 = {
    "name" : ['Harry', 'Rohan', 'Ayushi', 'Sim'],
    "marks" : [93, 83, 91, 90],
    "city" : ['Jaipur', 'Rampur', 'Agra', 'Kolkata']
}

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#      name  marks     city
# 0   Harry     93   Jaipur
# 1   Rohan     83   Rampur
# 2  Ayushi     91     Agra
# 3     Sim     90  Kolkata

# %%
df.to_csv('friend.csv')
